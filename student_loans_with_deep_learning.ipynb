# %% [markdown]
# # Student Loan Risk with Deep Learning

# %%
# Imports
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from pathlib import Path

# %% [markdown]
# ---
#
# ## Prepare the data to be used on a neural network model

# %% [markdown]
# ### Step 1: Read the `student-loans.csv` file into a Pandas DataFrame. Review the DataFrame, looking for columns that could eventually define your features and target variables.

# %%
# Read the csv into a Pandas DataFrame
file_path = "https://static.bc-edx.com/ai/ail-v-1-0/m18/lms/datasets/student-loans.csv"
loans_df = pd.read_csv(file_path)

# Review the DataFrame
loans_df.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# 2                  0.9970            3.26              0.65
# 3                  0.9980            3.16              0.58
# 4                  0.9978            3.51              0.56
#
#    financial_aid_score  credit_ranking
# 0                  9.4               0
# 1                  9.8               0
# 2                  9.8               0
# 3                  9.8               1
# 4                  9.4               0

# %%
# Review the data types associated with the columns
loans_df.dtypes
# Out:
# payment_history           float64
# location_parameter        float64
# stem_degree_score         float64
# gpa_ranking               float64
# alumni_success            float64
# study_major_code          float64
# time_to_completion        float64
# finance_workshop_score    float64
# cohort_ranking            float64
# total_loan_score          float64
# financial_aid_score       float64
# credit_ranking              int64
# dtype: object

# %%
# Check the credit_ranking value counts
loans_df["credit_ranking"].value_counts()
# Out:
# credit_ranking
# 1    855
# 0    744
# Name: count, dtype: int64

# %% [markdown]
# ### Step 2: Using the preprocessed data, create the features (`X`) and target (`y`) datasets. The target dataset should be defined by the preprocessed DataFrame column “credit_ranking”. The remaining columns should define the features dataset.

# %%
# Define the target set y using the credit_ranking column
y = loans_df['credit_ranking']

# Display a sample of y
y[:5]
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0
# Name: credit_ranking, dtype: int64

# %%
# Define features set X by selecting all columns but credit_ranking
X = loans_df.drop(columns='credit_ranking')

# Review the features DataFrame
X.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# 2                  0.9970            3.26              0.65
# 3                  0.9980            3.16              0.58
# 4                  0.9978            3.51              0.56
#
#    financial_aid_score
# 0                  9.4
# 1                  9.8
# 2                  9.8
# 3                  9.8
# 4                  9.4

# %% [markdown]
# ### Step 3: Split the features and target sets into training and testing datasets.

# %%
# Split the preprocessed data into a training and testing dataset
# Assign the function a random_state equal to 1
# # Split the features and target data
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %% [markdown]
# ### Step 4: Use scikit-learn's `StandardScaler` to scale the features data.

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the scaler to the features training dataset
X_scaler = scaler.fit(X_train)
X_train_scaled = X_scaler.transform(X_train)

# Fit the scaler to the features testing dataset
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ---
#
# ## Compile and Evaluate a Model Using a Neural Network

# %% [markdown]
# ### Step 1: Create a deep neural network by assigning the number of input features, the number of layers, and the number of neurons on each layer using Tensorflow’s Keras.
#
# > **Hint** You can start with a two-layer deep neural network model that uses the `relu` activation function for both layers.

# %%
# Define the the number of inputs (features) to the model
input_nodes = len(X.columns)

# nn_model.add(tf.keras.layers.Dense(units=5, activation="tanh", input_dim=input_features))



#nn_model.add(tf.keras.layers.Dense(units=5, activation="relu", input_dim=input_features))


# hidden_nodes_layer1 = 5
# hidden_nodes_layer2 = 5

# Review the number of features in the dataset

# nn_model.add(tf.keras.layers.Dense(units=5, activation="relu", input_dim=len(X_train.columns)))
# nn_model.add(tf.keras.layers.Dense(units=5, activation="relu"))

# Review the number of features
# nn_model.summary()

input_nodes
# Out:
# 11

# %%
# Define the number of hidden nodes for the first hidden layer
# nn_model.add(tf.keras.layers.Dense(units=5, activation="tanh", input_dim=len(X_train.columns)))
num_hidden_nodes1 = 6

# Define the number of hidden nodes for the second hidden layer
# nn_model.add(tf.keras.layers.Dense(units=5, activation="tanh", input_dim=len(X_train.columns)))
num_hidden_nodes2 = 3

# Define the number of neurons in the output layer
# nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
num_hidden_nodes_out = 1

# %%
# Create the Sequential model instance
nn_model = tf.keras.models.Sequential()

# Add the first hidden layer
nn_model.add(tf.keras.layers.Dense(units=num_hidden_nodes1, activation="relu", input_dim=input_nodes))

# Add the second hidden layer
nn_model.add(tf.keras.layers.Dense(units=num_hidden_nodes2, activation="relu"))

# Add the output layer to the model specifying the number of output neurons and activation function
nn_model.add(tf.keras.layers.Dense(units=num_hidden_nodes_out, activation="sigmoid"))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Display the Sequential model summary
nn_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 6)                   │              72 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 3)                   │              21 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │               4 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 97 (388.00 B)
#  Trainable params: 97 (388.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Step 2: Compile and fit the model using the `binary_crossentropy` loss function, the `adam` optimizer, and the `accuracy` evaluation metric.

# %%
# Compile the Sequential model
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Fit the model using 50 epochs and the training data
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4645 - loss: 0.7828
# Epoch 2/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4868 - loss: 0.7360
# Epoch 3/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5428 - loss: 0.6966
# Epoch 4/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5388 - loss: 0.6749
# Epoch 5/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5849 - loss: 0.6504
# Epoch 6/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6314 - loss: 0.6354
# Epoch 7/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6879 - loss: 0.6083
# Epoch 8/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6974 - loss: 0.6129
# Epoch 9/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6923 - loss: 0.5973
# Epoch 10/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6917 - loss: 0.5959
# Epoch 11/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7023 - loss: 0.5842
# Epoch 12/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7336 - loss: 0.5587
# Epoch 13/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7202 - loss: 0.5666
# Epoch 14/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7348 - loss: 0.5536
# Epoch 15/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7423 - loss: 0.5405
# Epoch 16/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7333 - loss: 0.5533
# Epoch 17/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7426 - loss: 0.5415
# Epoch 18/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7437 - loss: 0.5370
# Epoch 19/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7087 - loss: 0.5469
# Epoch 20/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7381 - loss: 0.5224
# Epoch 21/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7236 - loss: 0.5304
# Epoch 22/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7576 - loss: 0.5081
# Epoch 23/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7512 - loss: 0.5123
# Epoch 24/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7463 - loss: 0.5140
# Epoch 25/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7330 - loss: 0.5273
# Epoch 26/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7189 - loss: 0.5538
# Epoch 27/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7371 - loss: 0.5135
# Epoch 28/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7313 - loss: 0.5387
# Epoch 29/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7334 - loss: 0.5141
# Epoch 30/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7385 - loss: 0.5202
# Epoch 31/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7477 - loss: 0.5223
# Epoch 32/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7428 - loss: 0.5299
# Epoch 33/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7596 - loss: 0.5103
# Epoch 34/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7716 - loss: 0.5018
# Epoch 35/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7491 - loss: 0.5099
# Epoch 36/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7497 - loss: 0.5141
# Epoch 37/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7533 - loss: 0.5076
# Epoch 38/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7540 - loss: 0.5059
# Epoch 39/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7398 - loss: 0.5285
# Epoch 40/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7512 - loss: 0.4979
# Epoch 41/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7768 - loss: 0.4931
# Epoch 42/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7646 - loss: 0.4957
# Epoch 43/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7601 - loss: 0.5090
# Epoch 44/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7471 - loss: 0.5113
# Epoch 45/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7492 - loss: 0.5104
# Epoch 46/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7510 - loss: 0.5221
# Epoch 47/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5465
# Epoch 48/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7699 - loss: 0.4901
# Epoch 49/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7745 - loss: 0.5071
# Epoch 50/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7793 - loss: 0.4837

# %% [markdown]
# ### Step 3: Evaluate the model using the test data to determine the model’s loss and accuracy.

# %%
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)

# Display the model loss and accuracy results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 13/13 - 0s - 13ms/step - accuracy: 0.7375 - loss: 0.5124
# Loss: 0.5124475359916687, Accuracy: 0.737500011920929

# %% [markdown]
# ### Step 4: Save and export your model to a keras file, and name the file `student_loans.keras`.

# %%
# Set the model's file path
file_path = Path("student-loans.keras")

# Export your model to a keras file
nn_model.save(file_path)

# %% [markdown]
# ---
# ## Predict Loan Repayment Success by Using your Neural Network Model

# %% [markdown]
# ### Step 1: Reload your saved model.

# %%
# Set the model's file path
# file_path = Path("sports-articles.keras")
file_path = Path("student-loans.keras")

# Load the model to a new object
nn_imported = tf.keras.models.load_model(file_path)

# %% [markdown]
# ### Step 2: Make predictions on the testing data and save the predictions to a DataFrame.

# %%
# Make predictions with the test data

# predictions = nn_model.predict(X_test_scaled,verbose=2)
predictions = nn_model.predict(X_test_scaled,verbose=2)
# predictions

# Display a sample of the predictions
predictions
# Out:
# 13/13 - 0s - 9ms/step
# array([[0.46204612],
#        [0.24498285],
#        [0.6253058 ],
#        [0.63690245],
#        [0.9869256 ],
#        [0.8007787 ],
#        [0.9055372 ],
#        [0.3486709 ],
#        [0.8670754 ],
#        [0.28982553],
#        [0.9168921 ],
#        [0.24423927],
#        [0.29899275],
#        [0.9438512 ],
#        [0.4600631 ],
#        [0.27885482],
#        [0.75344133],
#        [0.37030825],
#        [0.42222574],
#        [0.3812745 ],
#        [0.7703358 ],
#        [0.8529991 ],
#        [0.24343315],
#        [0.9496563 ],
#        [0.33152458],
#        [0.94237894],
#        [0.8491086 ],
#        [0.49508056],
#        [0.3205045 ],
#        [0.40673697],
#        [0.411545  ],
#        [0.95039105],
#        [0.18670902],
#        [0.92656434],
#        [0.13351387],
#        [0.5829383 ],
#        [0.22649035],
#        [0.31315342],
#        [0.94296426],
#        [0.19662988],
#        [0.83642745],
#        [0.22457558],
#        [0.10550778],
#        [0.9339266 ],
#        [0.19254293],
#        [0.79721355],
#        [0.1633219 ],
#        [0.30535963],
#        [0.33794585],
#        [0.84018326],
#        [0.41206983],
#        [0.35830176],
#        [0.8979943 ],
#        [0.15374509],
#        [0.28534752],
#        [0.7527481 ],
#        [0.836039  ],
#        [0.7970238 ],
#        [0.7277614 ],
#        [0.2697732 ],
#        [0.8727863 ],
#        [0.27164194],
#        [0.27845898],
#        [0.44747263],
#        [0.13410576],
#        [0.30582094],
#        [0.9448356 ],
#        [0.64043224],
#        [0.773583  ],
#        [0.9718388 ],
#        [0.13351387],
#        [0.94124866],
#        [0.638241  ],
#        [0.7995631 ],
#        [0.41153386],
#        [0.3730337 ],
#        [0.9012598 ],
#        [0.20300478],
#        [0.4058976 ],
#        [0.671838  ],
#        [0.75735086],
#        [0.21688747],
#        [0.15765911],
#        [0.55111843],
#        [0.42398247],
#        [0.23767343],
#        [0.17888424],
#        [0.8710068 ],
#        [0.3172075 ],
#        [0.74311185],
#        [0.19686861],
#        [0.92352957],
#        [0.1360481 ],
#        [0.9013341 ],
#        [0.7685522 ],
#        [0.192179  ],
#        [0.9346356 ],
#        [0.38600764],
#        [0.27838674],
#        [0.90191555],
#        [0.48819476],
#        [0.49347818],
#        [0.22280116],
#        [0.24879473],
#        [0.08274095],
#        [0.3825198 ],
#        [0.67488956],
#        [0.22187297],
#        [0.8170373 ],
#        [0.6245726 ],
#        [0.9725072 ],
#        [0.4911129 ],
#        [0.7235637 ],
#        [0.4975102 ],
#        [0.2715391 ],
#        [0.9834859 ],
#        [0.22293623],
#        [0.1925467 ],
#        [0.1909531 ],
#        [0.20993121],
#        [0.09553742],
#        [0.97152257],
#        [0.9409092 ],
#        [0.22863737],
#        [0.44295463],
#        [0.4434397 ],
#        [0.8355485 ],
#        [0.19372536],
#        [0.6804037 ],
#        [0.65739936],
#        [0.37631422],
#        [0.2592374 ],
#        [0.89460444],
#        [0.18476841],
#        [0.7680188 ],
#        [0.7909753 ],
#        [0.15390214],
#        [0.96939653],
#        [0.26255405],
#        [0.3291614 ],
#        [0.19183785],
#        [0.38277853],
#        [0.6857348 ],
#        [0.4212039 ],
#        [0.846518  ],
#        [0.91640806],
#        [0.5100091 ],
#        [0.22150803],
#        [0.63074505],
#        [0.73054105],
#        [0.33983797],
#        [0.95558137],
#        [0.29382086],
#        [0.23222378],
#        [0.8802358 ],
#        [0.8664129 ],
#        [0.9095803 ],
#        [0.90902406],
#        [0.86685663],
#        [0.40769804],
#        [0.7980631 ],
#        [0.72829974],
#        [0.3770994 ],
#        [0.27201164],
#        [0.94360936],
#        [0.8321247 ],
#        [0.21878555],
#        [0.21881737],
#        [0.16252881],
#        [0.77846193],
#        [0.31124595],
#        [0.848339  ],
#        [0.19180056],
#        [0.2557613 ],
#        [0.8833501 ],
#        [0.34646872],
#        [0.33313313],
#        [0.11222517],
#        [0.2665119 ],
#        [0.192179  ],
#        [0.6381102 ],
#        [0.9074963 ],
#        [0.6118699 ],
#        [0.3721669 ],
#        [0.92815584],
#        [0.974375  ],
#        [0.94574356],
#        [0.37614426],
#        [0.23021266],
#        [0.1744586 ],
#        [0.40320274],
#        [0.5563551 ],
#        [0.38017738],
#        [0.5279517 ],
#        [0.4920554 ],
#        [0.26101077],
#        [0.55162525],
#        [0.50675213],
#        [0.48315912],
#        [0.24321437],
#        [0.89176   ],
#        [0.37609816],
#        [0.9293521 ],
#        [0.2539223 ],
#        [0.97425354],
#        [0.71529144],
#        [0.23337594],
#        [0.1454725 ],
#        [0.85807115],
#        [0.710259  ],
#        [0.40486923],
#        [0.86185616],
#        [0.22280116],
#        [0.90633655],
#        [0.28318867],
#        [0.2572638 ],
#        [0.25624913],
#        [0.20458911],
#        [0.8335427 ],
#        [0.44466484],
#        [0.53606397],
#        [0.27786145],
#        [0.3559484 ],
#        [0.19094057],
#        [0.85376936],
#        [0.5759354 ],
#        [0.09951048],
#        [0.61892796],
#        [0.9731329 ],
#        [0.6271658 ],
#        [0.43402782],
#        [0.20469639],
#        [0.84832364],
#        [0.84042674],
#        [0.37181014],
#        [0.54229975],
#        [0.90198207],
#        [0.19610743],
#        [0.46761903],
#        [0.59775865],
#        [0.828974  ],
#        [0.8805034 ],
#        [0.4585517 ],
#        [0.4582458 ],
#        [0.44987896],
#        [0.9846304 ],
#        [0.6153522 ],
#        [0.34853062],
#        [0.10977709],
#        [0.18821433],
#        [0.1944586 ],
#        [0.21371727],
#        [0.9761248 ],
#        [0.68229884],
#        [0.9222832 ],
#        [0.2227678 ],
#        [0.3059553 ],
#        [0.26254636],
#        [0.31325272],
#        [0.67374444],
#        [0.8308576 ],
#        [0.25933963],
#        [0.6668227 ],
#        [0.22396651],
#        [0.3672862 ],
#        [0.63074505],
#        [0.6348791 ],
#        [0.16498502],
#        [0.12247926],
#        [0.9381993 ],
#        [0.31542876],
#        [0.534949  ],
#        [0.21647279],
#        [0.9639618 ],
#        [0.17723304],
#        [0.5730054 ],
#        [0.2870386 ],
#        [0.848339  ],
#        [0.43681636],
#        [0.26647106],
#        [0.9798766 ],
#        [0.7341085 ],
#        [0.49380165],
#        [0.17230392],
#        [0.20533493],
#        [0.7788799 ],
#        [0.59579664],
#        [0.5027848 ],
#        [0.11062129],
#        [0.66043884],
#        [0.5252842 ],
#        [0.75344133],
#        [0.5386381 ],
#        [0.3425763 ],
#        [0.9371621 ],
#        [0.909847  ],
#        [0.18985006],
#        [0.92712575],
#        [0.23191716],
#        [0.28329638],
#        [0.598883  ],
#        [0.9096892 ],
#        [0.22178748],
#        [0.6760779 ],
#        [0.3944614 ],
#        [0.45080993],
#        [0.22212844],
#        [0.9063607 ],
#        [0.74119085],
#        [0.13631189],
#        [0.53070265],
#        [0.6212009 ],
#        [0.5363866 ],
#        [0.9353246 ],
#        [0.33421174],
#        [0.6186961 ],
#        [0.24693981],
#        [0.21068731],
#        [0.84879714],
#        [0.90198207],
#        [0.36709562],
#        [0.4418521 ],
#        [0.99153066],
#        [0.19935808],
#        [0.26101077],
#        [0.6730101 ],
#        [0.19390042],
#        [0.9719254 ],
#        [0.71387815],
#        [0.46942398],
#        [0.70336497],
#        [0.25031477],
#        [0.20776469],
#        [0.4528485 ],
#        [0.378425  ],
#        [0.23710418],
#        [0.87118423],
#        [0.90633655],
#        [0.5169769 ],
#        [0.47736773],
#        [0.15562573],
#        [0.33249742],
#        [0.5663586 ],
#        [0.74320066],
#        [0.44287997],
#        [0.98555577],
#        [0.752988  ],
#        [0.32199612],
#        [0.20451483],
#        [0.25040558],
#        [0.86185616],
#        [0.9823211 ],
#        [0.35289973],
#        [0.78818905],
#        [0.46791318],
#        [0.3862295 ],
#        [0.98057616],
#        [0.9438512 ],
#        [0.15390214],
#        [0.12015196],
#        [0.12937403],
#        [0.87136954],
#        [0.4637072 ],
#        [0.9779136 ],
#        [0.33449525],
#        [0.29001945],
#        [0.264943  ],
#        [0.33317897],
#        [0.7890895 ],
#        [0.54229975],
#        [0.47475538],
#        [0.5621397 ],
#        [0.31749982],
#        [0.3460804 ],
#        [0.30505076],
#        [0.46069822],
#        [0.9891769 ],
#        [0.9743482 ],
#        [0.2572638 ],
#        [0.89061594],
#        [0.89126974],
#        [0.8090148 ],
#        [0.87688476],
#        [0.7511688 ],
#        [0.34634167],
#        [0.8401715 ],
#        [0.11850623],
#        [0.54533666],
#        [0.7179545 ],
#        [0.24206965],
#        [0.18226673],
#        [0.44448343],
#        [0.22304836],
#        [0.70251995],
#        [0.13384637],
#        [0.8288137 ],
#        [0.3172075 ],
#        [0.84832364],
#        [0.36817285],
#        [0.8420832 ]], dtype=float32)

# %%
# Save the predictions to a DataFrame and round the predictions to binary results
predictions_df = pd.DataFrame(columns=["predictions"], data=predictions)
predictions_df["predictions"] = round(predictions_df["predictions"],0)
predictions_df
# Out:
#      predictions
# 0            0.0
# 1            0.0
# 2            1.0
# 3            1.0
# 4            1.0
# ..           ...
# 395          1.0
# 396          0.0
# 397          1.0
# 398          0.0
# 399          1.0
#
# [400 rows x 1 columns]

# %% [markdown]
# ### Step 4: Display a classification report with the y test data and predictions

# %%
# Print the classification report with the y test data and predictions
print(classification_report(y_test, predictions_df["predictions"].values))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.79      0.74       188
#            1       0.79      0.69      0.74       212
#
#     accuracy                           0.74       400
#    macro avg       0.74      0.74      0.74       400
# weighted avg       0.74      0.74      0.74       400

# %% [markdown]
# ---
# ## Discuss creating a recommendation system for student loans

# %% [markdown]
# Briefly answer the following questions in the space provided:
#
# 1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.
#
# 2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.
#
# 3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.

# %% [markdown]
# **1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.**
#
#
# **2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.**
#
#
# **3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.**
